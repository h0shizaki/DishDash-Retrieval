# %%
import pandas as pd
import re

# %%
recipes_df = pd.read_csv('./resource/recipes.csv')
comment_df = pd.read_csv('./resource/reviews.csv')

# %%
comment_df.dropna(inplace=True)
recipes_df.dropna(inplace=True)

# %%
indexImage = recipes_df[( recipes_df['Images'] == 'character(0)')].index
recipes_df.drop(indexImage, inplace=True)

indexImage = recipes_df[(recipes_df['Images'] == 'c("")' )].index
recipes_df.drop(indexImage, inplace=True)

# %%
recipes_df.to_csv('./out/recipes.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### Insert to database

# %%
import pymongo

# %%
import re

def convert_to_array(string):
    # Remove leading and trailing quotation marks if present
    string = string.strip('"\'')

    # Check if the input string is empty
    if not string:
        return []  # Return an empty list if the input is empty

    # Check if the input string contains "c(" and ")"
    if 'c(' in string and ')' in string:
        # Use regular expression to split the string at commas, considering quotes and spaces
        array = re.findall(r'"[^"]*"|[^",\s]+', string)

        array[:] = (value for value in array if value != '')        
        array[:] = (value for value in array if value != 'c(')        
        array[:] = (value for value in array if value != ')')        
        array[:] = (value for value in array if value != ' ')        
        # Remove any leading or trailing whitespace from each element
        array = [s.strip('"') for s in array]
        return list(set(array))
    else:
        return list(set([string]))  # Return the input string as a single-element list

# %%
client = pymongo.MongoClient("mongodb://root:123456@localhost:27017/?authMechanism=DEFAULT")
db = client["IR"] 
col = db["recipe"] 

cleaned_recipe_collection = db['cleaned_recipe']

for recipe in col.find({}): 
    cleaned_recipe = {
        'RecipeId': recipe['RecipeId'] ,
        'Name': recipe['Name']  ,
        'AuthorId': recipe['AuthorId'] ,
        'AuthorName': recipe['AuthorName'] ,
        'CookTime':  recipe['CookTime'] ,
        'PrepTime':  recipe['PrepTime'],
        'TotalTime': recipe['TotalTime'] ,
        'DatePublished': recipe['DatePublished'] ,
        'Description': recipe['Description'],
        'Images': convert_to_array(recipe['Images']),
        'RecipeCategory': recipe['RecipeCategory'],
        'Keywords': convert_to_array(recipe['Keywords']),
        'RecipeIngredientQuantities': convert_to_array(recipe['RecipeIngredientQuantities']),
        'RecipeIngredientParts':  convert_to_array(recipe['RecipeIngredientParts']),
        'AggregatedRating': recipe['AggregatedRating'],
        'Calories': recipe['Calories'],
        'FatContent': recipe['FatContent'],
        'SaturatedFatContent': recipe['SaturatedFatContent'],
        'CholesterolContent': recipe['CholesterolContent'],
        'SodiumContent': recipe['SodiumContent'],
        'CarbohydrateContent': recipe['CarbohydrateContent'],
        'FiberContent': recipe['FiberContent'],
        'SugarContent': recipe['SugarContent'],
        'ProteinContent': recipe['ProteinContent'],
        'RecipeServings': recipe['RecipeServings'],
        'RecipeYield': recipe['RecipeYield'],
        'RecipeInstructions':  convert_to_array(recipe['RecipeInstructions']),
    }

    # print(cleaned_recipe)
    cleaned_recipe_collection.insert_one(cleaned_recipe)

# %%
client = pymongo.MongoClient("mongodb://root:123456@localhost:27017/?authMechanism=DEFAULT")
db = client["IR"] 
col = db["recipe"] 
cleaned_recipe_collection = db['cleaned_recipe']

# %% [markdown]
# ### Try Query

# %%
myquery = { "RecipeCategory": "Quick Breads" }
results = cleaned_recipe_collection.find(myquery).limit(5)

for match in results:
    print(match)
# Out:
# {'_id': ObjectId('65d5e48d8598535be43eb8f5'), 'RecipeId': '220', 'Name': 'Chocolate Zucchini Bread', 'AuthorId': '1604', 'AuthorName': 'itsjustme', 'CookTime': 'PT1H', 'PrepTime': 'PT25M', 'TotalTime': 'PT1H25M', 'DatePublished': '1999-08-07T09:18:00Z', 'Description': 'Make and share this Chocolate Zucchini Bread recipe from Food.com.', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/2rp90sY9Q96l93ATXIsR_zucchinnibread1%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/pic6dBbjd.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/zrkZ5Dc3RdyIotK1LwV7_IMG_4718.JPG', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/NiKUyiO5Tt2T3IQzUpRi_IMG_4717.JPG', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picVl9WPD.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/Odj8qst8T1eVOImGOCWg_image.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/pic0sEwXu.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picuHKLvl.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/ox0bM5LFTvamSUZZrvGJ_zucchinnibread2%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/V4O52EGNQlCwno2EDOa4_zucchinnibread3%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picdChvnL.jpg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/220/WgGTZM7mSLeMEnLraslw_IMG_4717.JPG', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picAqmOmd.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Sweet', 'Vegetable', 'Weeknight', 'Breads', 'Oven', '< 4 Hours'], 'RecipeIngredientQuantities': ['2', '1/2', '2 1/2', '1', '1/4', '3'], 'RecipeIngredientParts': ['salt', 'vanilla extract', 'all-purpose flour', 'eggs', 'cinnamon', 'baking powder', 'baking soda', 'zucchini', 'sugar'], 'AggregatedRating': '5.0', 'Calories': '501.2', 'FatContent': '24.2', 'SaturatedFatContent': '3.7', 'CholesterolContent': '55.8', 'SodiumContent': '392.8', 'CarbohydrateContent': '67.6', 'FiberContent': '2.7', 'SugarContent': '40.9', 'ProteinContent': '6.3', 'RecipeServings': '10.0', 'RecipeYield': '2 loaves', 'RecipeInstructions': ['Bake at 350°F for 1 hour or until bread tests done.  Makes 2 loaves.', 'In a mixing bowl, beat eggs, oil, sugar and vanilla.', 'Pour into two greased 8x4x3-inch loaf pans.', 'Stir in zucchini.', 'Combine dry ingredients; add to zucchini mixture and mix well.']}
# {'_id': ObjectId('65d5e48d8598535be43eb8f6'), 'RecipeId': '221', 'Name': 'Chocolate Chip Muffins', 'AuthorId': '1752', 'AuthorName': 'Bob Ross', 'CookTime': 'PT40M', 'PrepTime': 'PT55M', 'TotalTime': 'PT1H35M', 'DatePublished': '1999-09-12T05:54:00Z', 'Description': 'When I find my bananas getting too ripe I freeze them for later use.  Just thaw them in the microwave when you want to use.  Here is a recipe for chocolate chip muffins that uses one banana. They even taste healthy :-)', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/1/picmE4uiZ.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/1/picjXaLFo.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Breads', 'Oven', '< 4 Hours', 'Weeknight'], 'RecipeIngredientQuantities': ['2', '2 1/2', '1 3/4', '1/3', '1', '1/2'], 'RecipeIngredientParts': ['butter', 'brown sugar', 'all-purpose flour', 'eggs', 'baking powder', 'milk', 'whole wheat flour', 'chocolate chips', 'banana'], 'AggregatedRating': '5.0', 'Calories': '264.6', 'FatContent': '11.2', 'SaturatedFatContent': '6.5', 'CholesterolContent': '51.6', 'SodiumContent': '139.4', 'CarbohydrateContent': '38.8', 'FiberContent': '2.2', 'SugarContent': '17.8', 'ProteinContent': '5.0', 'RecipeServings': '12.0', 'RecipeYield': '12 muffins', 'RecipeInstructions': ['Cool on  racks.', 'Bake 25 minutes or until browned slightly.', 'Combine mashed banana with brown sugar until smooth.', 'Preparation time 15 minutes, Cooking Time 25 minutes, Yield 12 large muffins.', 'Beat in eggs, milk and melted butter.', 'Quickly stir in chocolate chips. Do not overbeat.', 'Sift together all-purpose flour, whole wheat flour, and baking powder. Reserve.', 'Spoon mixture into prepared muffin cups. An ice cream scoop  works  well for this.', 'Stir in dry ingredients only until blended.', 'Preheat oven to 400 degrees Fahrenheit.', 'The banana and chocolate chips give the muffin a nice flavour and it is not overly sweet.  Tastes almost healthy :-).', "RJ's Note: Tested recipe August 31, 1999.", 'Butter 12 large muffin pans well or line with  paper muffin cups.', 'I substituted 1/3 cup canola oil instead of butter.']}
# {'_id': ObjectId('65d5e48d8598535be43eb8f8'), 'RecipeId': '469', 'Name': 'Irish Dark Soda Bread', 'AuthorId': '1612', 'AuthorName': 'JANIC412', 'CookTime': 'PT45M', 'PrepTime': 'PT15M', 'TotalTime': 'PT1H', 'DatePublished': '1999-08-28T02:41:00Z', 'Description': 'Make and share this Irish Dark Soda Bread recipe from Food.com.', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/46/9/picxDWQwQ.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Easy', 'European', 'Low Cholesterol', '< 60 Mins', "St. Patrick's Day", 'For Large Groups', 'Breads', 'Oven', 'Healthy'], 'RecipeIngredientQuantities': ['3', '2 1/2', '2', '1'], 'RecipeIngredientParts': ['brown sugar', 'all-purpose flour', 'baking powder', 'whole wheat flour', 'buttermilk', 'baking soda'], 'AggregatedRating': '5.0', 'Calories': '158.4', 'FatContent': '0.8', 'SaturatedFatContent': '0.3', 'CholesterolContent': '1.5', 'SodiumContent': '267.5', 'CarbohydrateContent': '32.5', 'FiberContent': '2.5', 'SugarContent': '3.6', 'ProteinContent': '5.7', 'RecipeServings': '16.0', 'RecipeYield': '2 loaves', 'RecipeInstructions': ['Bake for about 45 minutes or until brown and crunchy.', 'Grease two loaf pans.', 'Preheat oven to 400 degrees Fahrenheit.', 'Add buttermilk and stir well.', 'Divide the dough between the two prepared loaf pans.', 'Cool on wire racks.', 'Add brown sugar and stir well to incorporate, being very careful to break up any lumps of brown sugar.', 'Sift all-purpose flour, whole wheat flour, baking soda and baking powder together into a large bowl.']}
# {'_id': ObjectId('65d5e48d8598535be43eb903'), 'RecipeId': '1387', 'Name': 'Perfectly Spiced Banana Bread', 'AuthorId': '1762', 'AuthorName': 'lkadlec', 'CookTime': 'PT1H5M', 'PrepTime': 'PT0S', 'TotalTime': 'PT1H5M', 'DatePublished': '1999-09-26T20:49:00Z', 'Description': 'Make and share this Perfectly Spiced Banana Bread recipe from Food.com.', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picTCvw41.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picvEgy8H.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/pictmifEI.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picXRm3IC.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/01474810343.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picPe8i1s.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picvSyOTM.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picD8K5Vt.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/01480807071.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/13/87/picveZhgu.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Breads', 'Oven', 'Fruit', '< 4 Hours'], 'RecipeIngredientQuantities': ['2', '3/4', '1 3/4', '1 1/2', '1', '1/4', '1/2'], 'RecipeIngredientParts': ['butter', 'nutmeg', 'salt', 'all-purpose flour', 'allspice', 'bananas', 'eggs', 'sugar', 'lemon zest', 'baking powder', 'margarine', 'ginger', 'baking soda'], 'AggregatedRating': '5.0', 'Calories': '318.2', 'FatContent': '13.1', 'SaturatedFatContent': '7.8', 'CholesterolContent': '77.0', 'SodiumContent': '434.9', 'CarbohydrateContent': '46.6', 'FiberContent': '1.5', 'SugarContent': '22.3', 'ProteinContent': '4.8', 'RecipeServings': '8.0', 'RecipeYield': '1 loaf', 'RecipeInstructions': ['Cool in pan on wire rack 10 minutes.', 'Add 3/4 cup coarsely chopped walnuts or pecans with bananas.', 'Bake in center of oven 1 hour to 1 hour 5 minutes, or until toothpick inserted in center comes out clean.', 'Sift flour,baking powder,  baking soda, salt, ginger, allspice and nutmeg together in bowl.', 'Add eggs and beat until thoroughly blended.', 'Grease 9 x 5 inch loaf pan.', 'Beat in flour mixture alternately with bananas until mixture is well blended.', 'Pour into prepared pan.', 'Beat in sugar until light and fluffy.', 'Invert from pan and cool completely on rack.', 'Variation: Banana-walnut or -pecan bread: Omit almonds.', 'Stir until combined.', 'Set aside. Beat butter in large mixing bowl until soft and creamy.', 'Add lemon zest and almonds.', 'Preheat oven to 350°F.']}
# {'_id': ObjectId('65d5e48d8598535be43eb911'), 'RecipeId': '2886', 'Name': 'Best Banana Bread', 'AuthorId': '1762', 'AuthorName': 'lkadlec', 'CookTime': 'PT1H', 'PrepTime': 'PT10M', 'TotalTime': 'PT1H10M', 'DatePublished': '1999-09-26T20:49:00Z', 'Description': 'Make and share this Best Banana Bread recipe from Food.com.', 'Images': ['https://img.sndimg.com/food/image/upload/v1/img/feed/2886/xQbbDp8RUmqkN5N76Lry_IMG_20171216_175348294.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/picvmRfkh.jpg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/g2B8UGjPQ3C5PDE1kFNk_20170925_154000.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/okAJswDtRiWUcWXVtz0v_8702033F-6CDF-4EF8-8E7A-A3629D12B89B.jpeg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/4FiZlgWcQHpSZyVbBtAe_20191227_191735.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/picF8zR6u.jpg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/aX857DbXTzW3ki2n69SW_74AE5A9A-BF59-4390-9090-C36E6BD25221.jpeg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/T421RX6MQFyS9Ilb69Tg_FE70676E-B1D9-483E-84E4-0837E38E07C8.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/01490814539.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/cCRiwXkTxu75poZTLQJG_BananaBread10-10-14%203698.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/XI4HcLySQ5KBpsFPLe9Z_image.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/rjvr9WorQYKV5Dpek2ND_864D9967-A82B-4B4D-AB38-C8BCBD53307B.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/qTOTUSRTISmdK24iIVHz_IMG_7919.jpg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/556qfEBvR4iVnRppWj09_IMG_1072.JPG', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/fmqP9a9dSq6fxxTPGTUA_image.jpeg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/fuVxgeT8SkeB5Pp2rFsQ_IMG_20180206_212152.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/gGiCD0tIRPS7YsOaH4t0_10156731880515821.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/ZuEPa2kSwahldCaoLowO_2641600065962248.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/lsRGHo6KRuKhvguS6mOx_6F29D3D8-1FCB-4539-BB33-E228EBAD185D.jpeg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/GHMWerOIQAS5mv7TLgwL_IMG_20200528_232134_163.jpg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/t8jRwNXeQG6z68IPFKY6_IMG_2817.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/bQGDGPVZQUy7sIpwQd1j_3720531927988583.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/kEj9DmIrQcOZMfCPsVGo_1513803561224892388164.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/01497672501.jpeg', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/iBZ4BXQaig7n5NpxjwCO_IMG_4927.JPG', 'https://img.sndimg.com/food/image/upload/v1/img/feed/2886/8uFklpOSGCMUUapeTd8g_IMG_20171026_121400.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/cS7bXBBFSdeLUxxMQjMI_151467780786849768189.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/picQ9iR8C.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progr ...

# %% [markdown]
# ### Put the recipe into elasticsearch

# %%
from elasticsearch import Elasticsearch
import json
from bson import ObjectId
from elasticsearch import helpers

# %%
class ElasticIndexer:
    def __init__(self):
        self.es_client = Elasticsearch('https://localhost:9200', basic_auth=("elastic", "6E0GWL_MEddnKJWCnk*M"),
                    ca_certs="./http_ca.crt")
        self.mongo_client = pymongo.MongoClient("mongodb://root:123456@localhost:27017/?authMechanism=DEFAULT")
        self.mongo_collection = self.mongo_client['IR']['cleaned_recipe']

    def run_indexer(self):
        self.es_client.indices.create(index='simple', ignore=400)
        self.es_client.indices.delete(index='simple', ignore=[400, 404])
        actions = []
        
        for doc in self.mongo_collection.find({}):
            _id = str(doc['_id'])
            del doc["_id"]
            action = {
                "_index": 'recipe',
                "_id": _id,
                "_source": doc
            }
            actions.append(action)

        response = helpers.bulk(self.es_client, actions)
        return response

# %%
es = ElasticIndexer()
# es.run_indexer()

# %%
es_client = Elasticsearch('https://localhost:9200', basic_auth=("elastic", "6E0GWL_MEddnKJWCnk*M"),
                    ca_certs="./http_ca.crt")

# %%
query = {
    "query_string": {
        "query": "Sweet Rolls Easy"
    }
}

results = es_client.search(index='recipe', query=query)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                                              Name  \
# 0                             Breakfast Egg Rolls
# 1                             Honey Orange Butter
# 2                             Easy Crunchy Toffee
# 3                 The Best Sweet Potato Casserole
# 4                                  Sweet Kielbasa
# 5           Hawaiian Bread Ham &amp; Cheese Rolls
# 6        Sweet Potato Pancakes With Caramel Sauce
# 7                                     Sweet Rolls
# 8   Mini Cajun Burgers With Easy R&eacute;moulade
# 9  Coconut Shrimp With Guava Sweet and Sour Sauce
#
#                                             Keywords  \
# 0                                [Brunch, < 60 Mins]
# 1  [Beginner Cook, Inexpensive, < 15 Mins, Low Pr...
# 2            [Easy, Beginner Cook, For Large Groups]
# 3  [Beginner Cook, Inexpensive, Potato, Kid Frien...
# 4                  [Potluck, For Large Groups, Meat]
# 5                                 [For Large Groups]
# 6  [< 30 Mins, Potato, Yam/Sweet Potato, Vegetabl...
# 7  [Sweet, Kid Friendly, Thanksgiving, For Large ...
# 8                                 [Cajun, < 30 Mins]
# 9  [< 30 Mins, Summer, Polynesian, Fruit, Weeknight]
#
#                                           Ingredient      score
# 0  [onion, green pepper, eggs, cheese, water, mil...  13.042132
# 1                         [honey, butter, margarine]  12.088933
# 2             [butter, chocolate chips, brown sugar]  11.833335
# 3  [vanilla, butter, salt, brown sugar, eggs, wal...  10.931320
# 4  [kielbasa, brown sugar, water, apple cider, on...  10.792521
# 5  [butter, prepared yellow mustard, deli ham, sw...  10.752760
# 6  [butter, canned sweet potatoes, ground allspic...  10.670794
# 7  [active dry yeast, butter, ground cinnamon, sa...  10.655209
# 8  [creole mustard, sausage, green leaf lettuce, ...  10.290481
# 9  [coconut flakes, panko breadcrumbs, white vine...  10.101153

# %% [markdown]
# ### Recommendations

# %%
# Get top 5 similar to the selected dish

query = { 
   "more_like_this":{
    # Breakfast Eggcake ID:'65d5e4928598535be43ec668' 
    "fields":["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],"like":[{"_id": '65d5e4928598535be43ec668'}],"min_term_freq":1,"min_doc_freq":5,"max_query_terms":20
    }
}

results = es_client.search(index='recipe', query=query, size=5)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                              Name  \
# 0              Breakfast Sandwich
# 1              Breakfast Brownies
# 2    On-The-Go Breakfast Sandwich
# 3       Twiced Baked Potato Skins
# 4  Simplified Banana Oat Pancakes
#
#                                             Keywords  \
# 0  [Beginner Cook, Kid Friendly, < 15 Mins, Stove...
# 1  [Kid Friendly, < 60 Mins, Toddler Friendly, Ea...
# 2  [Beginner Cook, Microwave, Pork, Meat, < 15 Mi...
# 3  [Potato, Kid Friendly, < 15 Mins, Vegetable, C...
# 4  [Beginner Cook, Inexpensive, Kid Friendly, < 1...
#
#                                           Ingredient      score
# 0  [butter, bagel, ham, sausages, cream cheese, c...  24.269608
# 1      [skim milk, applesauce, egg, Bisquick, sugar]  22.526520
# 2         [cheese, English muffin, milk, egg, bacon]  22.497570
# 3  [monterey jack and cheddar cheese blend, parsl...  22.332865
# 4  [nutmeg, banana, all-purpose flour, canola oil...  22.148333

# %% [markdown]
# ### Personalized by interestedCategory

# %%
users = db['users']

user = users.find({'username': 'KanK'})
user_df = pd.DataFrame(user)

# %%
user_df['interestedCategory'][0]
# Out:
# ['Beginner Cook', 'Kid Friendly', 'Easy']

# %%
query = {
    "match": {
        "Keywords": {
        "query": ' '.join(user_df['interestedCategory'][0])
        }
    }
}

results = es_client.search(index='recipe', query=query, size=15)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                                                Name  \
# 0         --V's Kicked up Baked Beans (Slow Cooker)
# 1                         Easy Grands Cheese Pizzas
# 2                        Seasoned Goldfish Crackers
# 3                       Mama Mac's Bundt Pound Cake
# 4                                    Loco Hot Cocoa
# 5            Annie's Melt-In-Your-Mouth Mahi (Fish)
# 6                      Garlic Shrimp and Orzo Salad
# 7                              2bleu's 2easy Boboli
# 8                         Bolognese Style Pan Pizza
# 9                           Delicious Walking Tacos
# 10  T.v. Eggs - Kids Favorite Fun to Eat Breakfast!
# 11                                      Mallow-Cano
# 12                 President Nixon's Spanish Omelet
# 13                                Breakfast Eggcake
# 14           Absolutely the Best Southern Sweet Tea
#
#                                              Keywords  \
# 0                 [Easy, Beginner Cook, Kid Friendly]
# 1      [Easy, Beginner Cook, Kid Friendly, < 30 Mins]
# 2      [Easy, Beginner Cook, Kid Friendly, < 30 Mins]
# 3      [Easy, Beginner Cook, Kid Friendly, < 60 Mins]
# 4      [Easy, Beginner Cook, Kid Friendly, < 15 Mins]
# 5      [Easy, Beginner Cook, Kid Friendly, < 30 Mins]
# 6      [Easy, Beginner Cook, Kid Friendly, < 15 Mins]
# 7      [Easy, Beginner Cook, Kid Friendly, < 30 Mins]
# 8      [Easy, Beginner Cook, Kid Friendly, < 60 Mins]
# 9      [Easy, Beginner Cook, Kid Friendly, < 15 Mins]
# 10     [Easy, Beginner Cook, Kid Friendly, < 15 Mins]
# 11     [Easy, Beginner Cook, Kid Friendly, < 15 Mins]
# 12  [Beginner Cook, Kid Friendly, < 60 Mins, Toddl...
# 13  [Beginner Cook, Kid Friendly, < 15 Mins, Toddl...
# 14  [Beginner Cook, Inexpensive, Kid Friendly, Cam...
#
#                                            Ingredient     score
# 0   [barbecue sauce, pinto beans, ketchup, honey, ...  9.920821
# 1                                 [mozzarella cheese]  8.867212
# 2   [garlic powder, cayenne pepper, lemon-pepper s...  8.867212
# 3   [vanilla, powdered sugar, eggs, instant lemon ...  8.867212
# 4                              [instant coffee, milk]  8.867212
# 5   [dried dill weed, fresh rosemary, dried rosema...  8.867212
# 6   [cucumber, green pepper, red onion, raw shrimp...  8.867212
# 7   [active dry yeast, instant minced garlic, salt...  8.867212
# 8   [Italian sausage, ricotta cheese, lean ground ...  8.867212
# 9   [lettuce, sour cream, ground beef, cheddar che...  8.867212
# 10                       [butter, eggs, salt, pepper]  8.867212
# 11                                     [marshmallows]  8.867212
# 12  [diced tomato, butter, salt, fresh ground pepp...  8.757416
# 13   [butter, nutmeg, parsley, milk, egg, bacon bits]  8.757416
# 14                [water, tea bags, granulated sugar]  8.757416

# %% [markdown]
# ### Score by weight

# %%
query = {
    "dis_max": {
        "queries": [
            {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # Anzac Biscuits
                    "like": [{"_id": "65d5e48d8598535be43eb8f3"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 1.5
                }
            },
            {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # TOFU KEBAB
                    "like": [{"_id": "65d5e48d8598535be43eb8f1"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 1
                }
            }
            #   More Recipe in bookmarks 
            #   Does boost make sense or not?
        ]
    }
}


results = es_client.search(index='recipe', query=query, size=15)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                                                  Name  \
# 0                                      Anzac Biscuits
# 1                                      Anzac Biscuits
# 2                            Anzac Biscuits (Cookies)
# 3                            Chocolate Anzac Biscuits
# 4                                      Anzac Biscuits
# 5         Anzac Biscuits With Macadamias (Australian)
# 6                       Healthy Vegetable Tofu Kebabs
# 7   Crunchy Ginger Snaps (Similar to Arnotts Ginge...
# 8                                 Whole Grain Cookies
# 9                          Tofu and Bok Choy Stir Fry
# 10                         Tasty Tofu Veggie Scramble
# 11                      Pf Chang's Tofu Lettuce Wraps
# 12           Spicy &quot;Barbecued&quot; Tofu Burgers
# 13                                      Barbecue Tofu
# 14                            Vegan Baked Tofu Strips
#
#                                              Keywords  \
# 0   [Beginner Cook, Inexpensive, < 60 Mins, For La...
# 1   [< 30 Mins, Cookie & Brownie, Australian, Grai...
# 2   [Inexpensive, Free Of..., Kid Friendly, Egg Fr...
# 3   [Beginner Cook, < 30 Mins, Cookie & Brownie, F...
# 4   [< 30 Mins, Cookie & Brownie, Australian, Dess...
# 5   [< 30 Mins, Coconut, Free Of..., Egg Free, Swe...
# 6              [< 30 Mins, Peppers, Vegetable, Beans]
# 7                            [Easy, For Large Groups]
# 8   [Brunch, < 30 Mins, Summer, Cookie & Brownie, ...
# 9   [Vegan, < 15 Mins, Chinese, Vegetable, Low Cho...
# 10  [Vegan, < 30 Mins, Lactose Free, Free Of..., E...
# 11                   [Vegan, Asian, Beans, < 60 Mins]
# 12  [Soy/Tofu, Inexpensive, Broil/Grill, Vegetable...
# 13  [Beginner Cook, Inexpensive, Brunch, Vegan, Su...
# 14  [Vegan, Microwave, Free Of..., < 60 Mins, Potl...
#
#                                            Ingredient      score
# 0   [butter, plain flour, coconut, rolled oats, go...  74.877330
# 1   [butter, plain flour, lemon rind, rolled oats,...  71.968285
# 2   [butter, plain flour, brown sugar, rolled oats...  71.250610
# 3   [butter, plain flour, rolled oats, dark cookin...  68.098434
# 4   [butter, coconut, golden syrup, boiling water,...  65.139770
# 5   [butter, plain flour, white sugar, rolled oats...  56.711666
# 6   [firm tofu, salt, green pepper, button mushroo...  51.347355
# 7   [butter, self raising flour, eggs, golden syru...  44.894890
# 8   [Weetabix, brown sugar, rolled oats, golden sy...  39.848045
# 9   [bok choy, low sodium soy sauce, extra firm to...  39.541008
# 10  [garlic powder, green bell pepper, low sodium ...  36.966827
# 11  [garlic, brown sugar, extra firm tofu, water, ...  36.858364
# 12  [pickle, barbecue sauce, lemon-pepper seasonin...  35.296402
# 13  [firm tofu, onion powder, blackstrap molasses,...  34.937300
# 14  [panko breadcrumbs, sea salt, poultry seasonin...  34.552876

# %% [markdown]
# ### Not interested topic?

# %%
prefer = ['Beginner Cook', 'Kid Friendly', 'Easy'] # boost up

un_prefer = ['Australian', 'For Large Groups', 'Oven'] # boost down

query = {
    "dis_max": {
        "queries": [
            {
                "query_string": {
                    "query": ' '.join(prefer),
                    "boost": 1.2
                }
            },
            {
                "query_string": {
                    "query": ' '.join(un_prefer),
                    "boost": 0.8
                }                
            }
        ]
    }
}

results = es_client.search(index='recipe', query=query, size=100)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score']).sort_values(by=['score'], ascending=True)

print('Unprefer recipe score')
print(results_df.head().to_markdown())
print('Prefer recipe score')
print(results_df.tail().to_markdown())
# Out:
# Unprefer recipe score
# |    | Name                                  | Keywords                             | Ingredient                                                                                                                                                                                                                                            |   score |
# |---:|:--------------------------------------|:-------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# | 99 | Fresh Pumpkin (Canned, Puree, Frozen) | ['Easy', 'Inexpensive', '< 4 Hours'] | ['pumpkin']                                                                                                                                                                                                                                           | 10.2978 |
# | 82 | Deep Dish Pizza                       | ['Oven', '< 4 Hours']                | ['oregano', 'cornmeal', 'water', 'basil leaves', 'garlic cloves', 'parmesan cheese', 'quick-rising yeast', 'mozzarella cheese', 'canned plum tomatoes', 'olive oil', 'flour']                                                                         | 10.2978 |
# | 83 | Amazing Thin Crust Pizza              | ['Oven', '< 4 Hours']                | ['minced garlic cloves', 'salt', 'oregano', 'instant yeast', 'ground fennel', 'dried basil', 'bread flour', 'sausage', 'crushed tomatoes', 'tomato sauce', 'mild cheddar cheese', 'provolone cheese', 'mozzarella cheese', 'warm water', 'olive oil'] | 10.2978 |
# | 84 | Sourdough Doggie Biscuits             | ['< 4 Hours']                        | ['oats', 'pumpkin', 'bacon drippings', 'eggs', 'whole wheat flour', 'peanut butter']                                                                                                                                                                  | 10.2978 |
# | 85 | Allendale Dip                         | ['Inexpensive']                      | ['garlic powder', 'salt', 'sour cream', 'parmesan cheese', 'lemon juice', 'mayonnaise', 'fresh parsley', 'red pepper flakes', 'mozzarella cheese', 'sugar']                                                                                           | 10.2978 |
# Prefer recipe score
# |    | Name                                  | Keywords                                                                                                                                                   | Ingredient                                                                                                                                                                                               |   score |
# |---:|:--------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# |  4 | Meatballs in Buttermilk Sauce         | ['Easy', 'Kid Friendly', '< 4 Hours']                                                                                                                      | ['green bell pepper', 'salt', 'egg', 'ground beef', 'mushrooms', 'cooked rice', 'buttermilk', 'pepper', 'celery']                                                                                        | 16.8212 |
# |  3 | Ballpark Hot Dogs (Vegan)             | ['Kid Friendly', '< 60 Mins', 'Toddler Friendly']                                                                                                          | ['ground cumin', 'ground allspice', 'brown sugar', 'garlic clove', 'water', 'vital wheat gluten', 'ketchup', 'soy sauce', 'ground coriander', 'onion', 'white pepper', 'olive oil', 'nutritional yeast'] | 17.2434 |
# |  2 | Quick Burger Cups                     | ['Beginner Cook', 'Inexpensive', '< 30 Mins', 'Kid Friendly', 'Easy', 'Oven']                                                                              | ['cheddar cheese', 'barbecue sauce', 'ground beef']                                                                                                                                                      | 17.5283 |
# |  1 | Flaky Pie Crust                       | ['Inexpensive', 'Freezer', 'Christmas', 'Kid Friendly', 'Thanksgiving', '< 4 Hours', 'Dessert', 'For Large Groups', 'Weeknight', 'Easy', 'Oven', 'Winter'] | ['salt', 'all-purpose flour', 'apple cider vinegar', 'vegetable shortening', 'unsalted butter', 'margarine', 'sugar']                                                                                    | 19.8039 |
# |  0 | Crunchy Peanut Butter and Oats Spread | ['< 30 Mins', 'Kid Friendly', 'High In...', 'High Protein', 'Easy']                                                                                        | ['honey', 'old fashioned oats']                                                                                                                                                                          | 19.8621 |

# %% [markdown]
# ### Ranking evaluation

# %%
query = {
   "more_like_this":{
        "fields":["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],"like":[{"_id": "65d5e4928598535be43ec8fc"}],"min_term_freq":1,"min_doc_freq":5,"max_query_terms":20
    }
}

ratings = [
     { "_index": "recipe", "_id": "65d5e4928598535be43ec668", "rating": 0 },
     { "_index": "recipe", "_id": "65d5e48e8598535be43eba08", "rating": 3 },
     { "_index": "recipe", "_id": "65d5e4918598535be43ec3eb", "rating": 0 },
     { "_index": "recipe", "_id": "65d5e4928598535be43ec8fc", "rating": 5 },
     { "_index": "recipe", "_id": "65d5e49a8598535be43ee0c9", "rating": 2 },
     { "_index": "recipe", "_id": "65d5e49a8598535be43ee26f", "rating": 1 },
     { "_index": "recipe", "_id": "65d5e49b8598535be43ee65e", "rating": 4 },
     { "_index": "recipe", "_id": "65d5e49b8598535be43ee374", "rating": 5 },
]

requests = [
    { "id": "Query_1", "request": {"query": query} , 'ratings': ratings}
]

metric =  {
    "dcg": {
      "k": 20,
      "normalize": False
    }
}

results = es_client.rank_eval(index='recipe', requests=requests, metric= metric)
# mertic_score_df = pd.DataFrame()

# mertic_score_df
results['metric_score']
# Out:
# 0.7879486051115807

# %%
results_df = pd.DataFrame([[hit['hit']["_id"], hit['hit']["_score"], hit["rating"]] for hit in results['details']['Query_1']['hits']], columns=['ID', 'Score', 'Rating'])

results_df
# Out:
#                           ID      Score  Rating
# 0   65d5e4998598535be43edcb7  28.482512     NaN
# 1   65d5e4988598535be43edaa9  24.643640     NaN
# 2   65d5e4958598535be43ed1b5  22.636015     NaN
# 3   65d5e49c8598535be43ee9b2  20.707030     NaN
# 4   65d5e48e8598535be43ebb1d  20.245958     NaN
# 5   65d5e48f8598535be43ebd8e  19.682268     NaN
# 6   65d5e49c8598535be43ee9bd  19.554749     NaN
# 7   65d5e49b8598535be43ee5bc  19.258820     NaN
# 8   65d5e4968598535be43ed5fa  18.582226     NaN
# 9   65d5e4968598535be43ed422  18.580670     NaN
# 10  65d5e48e8598535be43ebaba  18.580053     NaN
# 11  65d5e48e8598535be43ebaaf  18.161040     NaN
# 12  65d5e49a8598535be43ee0c9  18.075802     2.0
# 13  65d5e4928598535be43ec5e1  17.762075     NaN
# 14  65d5e49e8598535be43ef002  17.362870     NaN
# 15  65d5e49e8598535be43ef0cc  17.272724     NaN
# 16  65d5e4928598535be43ec6cc  17.249142     NaN
# 17  65d5e4978598535be43ed69d  16.930267     NaN
# 18  65d5e4938598535be43ec97c  16.920275     NaN
# 19  65d5e49c8598535be43ee74e  16.778183     NaN
